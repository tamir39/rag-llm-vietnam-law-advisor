# %% [markdown]
# # 01 — Data Exploration
#
# Explore the VAT knowledge base CSV and any seed QA pairs.
# - Row counts, length distributions, duplicates
# - Sample passages by chapter / điều
# - Sanity-check Vietnamese text encoding

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from src.config import KB_CSV
