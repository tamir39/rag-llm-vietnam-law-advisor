# %% [markdown]
# # 03 — Fine-tune Qwen2.5-7B with QLoRA on Colab Free
#
# Runs in Colab Free (T4, 16GB). Steps:
# 1. Mount Drive / clone repo
# 2. Install peft + bitsandbytes + trl
# 3. Load base model in 4-bit
# 4. SFT on `data/qa/train_qa.jsonl`
# 5. Save adapter to Drive / push to HF Hub
